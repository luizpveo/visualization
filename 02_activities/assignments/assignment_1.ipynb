# %% [markdown]
# Class 1

# %%
import importlib

packages = ['numpy', 'matplotlib', 'pandas', 'scipy', 'PIL', 'requests', 'seaborn']

for package in packages:
    try:
        importlib.import_module(package)
        print(f'{package} is installed.')
    except ImportError:
        print(f'{package} is NOT installed.')
# Out:
# numpy is installed.
# matplotlib is installed.
# pandas is installed.
# scipy is installed.
# PIL is installed.
# requests is installed.
# seaborn is installed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
#Assign random seed for reproducability
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
#Create a scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %%
#Create a bar graph
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
#Create a line graph
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
#Create a histogram
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
#Assign title and axes names to the plotted line graph

#Plot line graph
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

#Assign title and axes names
ax.set_title("Total Growth Over Time")
ax.set_ylabel("Total Growth")
ax.set_xlabel("Years Since Start")
# Out:
# Text(0.5, 0, 'Years Since Start')

# %%
#Create dictionary for font, colour, and size
font1 = {'family': 'sans-serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'monospace', 'color': 'green', 'size': 14}

#Assign fonts, colours, and size using above dictionary to graph title and axes name elements from above code block
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title("Total Growth Over Time", fontdict = font1)
ax.set_ylabel("Total Growth", fontdict=font2)
ax.set_xlabel('Years Since Start', fontdict=font2)
# Out:
# Text(0.5, 0, 'Years Since Start')

# %%
#Change location of graph title
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

#Left justify graph title
ax.set_title('Total growth over time'
, fontdict = font1, loc = 'left')
ax.set_ylabel('Total growth'
, fontdict = font2)
ax.set_xlabel('Years since start'
, fontdict = font2)
fig.tight_layout()

# %%
#Change marker shape and colour (Marker = star, Colour = indigo)
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x,y,
marker='*'
, # NEW ADDITIONS
color = "indigo") # NEW ADDITIONS
fig.show()
# Out:
# C:\Users\luizp\AppData\Local\Temp\ipykernel_21048\2949646640.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
y,
marker='*'
,
color = 'indigo'
,
linestyle = '--'
, # NEW ADDITIONS
linewidth = 2) # NEW ADDITIONS
fig.show()
# Out:
# C:\Users\luizp\AppData\Local\Temp\ipykernel_21048\1577294754.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,marker='*',
        markersize=12,
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359',
        markerfacecolor='#000000')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,marker='*',
        markersize=12,
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359',
        markerfacecolor='#000000')

#Change gridlines to pink colour, and gridline style to dotted lines with line width 0.5
ax.grid(color = 'pink', linestyle = 'dotted', linewidth =0.5)

# %% [markdown]
# Class 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\luizp\AppData\Local\Temp\ipykernel_64216\3608551665.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.plot(x,y1,label = "Person 1")
ax.plot(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.plot(x,y1,label = "Person 1")
ax.plot(x,y2,label = "Person 2")
ax.legend(loc ="lower right",
        frameon = True,
        fontsize =12,
        ncol =2,
        shadow = True)

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.plot(x,y1,label = "Person 1")
ax.plot(x,y2,label = "Person 2")
ax.legend(loc ="upper left",
        bbox_to_anchor = (1,1))

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")
ax.text(10,95,"This value is important!")
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")
ax.text(10,95,"Some random words",
        ha = "center",
        color = "red",
        size = 20)
# Out:
# Text(10, 95, 'Some random words')

# %%
fig, ax= plt.subplots()
ax.axis([0, 10, 0, 10])

ax.text(1,5,"Data: (1,5)", transform = ax.transData)
ax.text(0.5,0.1,"Axes: (0.5,0.1)", transform = ax.transAxes)
ax.text(0.2,0.2,"Figure: (0.2,0.2)", transform = fig.transFigure)
# Out:
# Text(0.2, 0.2, 'Figure: (0.2,0.2)')

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

ax.annotate("This is important", xy = (10,95), xytext = (20,94),
            arrowprops = dict(facecolor = "black", 
                              shrink = 0.05))
# Out:
# Text(20, 94, 'This is important')

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

ax.annotate("This is important", xy = (10,95), xytext = (20,94),
            arrowprops = dict(arrowstyle = "wedge", 
                              color = "hotpink"))
# Out:
# Text(20, 94, 'This is important')

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

ax.yaxis.set_major_locator(plt.MaxNLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

plt.xticks(rotation = 45, ha = "right", fontsize = 12, font = "serif")
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
fig, ax= plt.subplots(figsize=(5, 3))
ax.scatter(x,y1,label = "Person 1")
ax.scatter(x,y2,label = "Person 2")
ax.legend(loc ="lower right")

font1 = {'family':'serif','color':'indigo'}
plt.xlabel("Shiny new X Axis",fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny new X Axis')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")

fig, ax= plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
plt.style.use('default')

fig, ax= plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
plt.style.use("bmh")

fig, ax= plt.subplots(figsize=(5, 3))
ax.plot(x,y1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y2 = np.array([110,180,240,99,220])

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2,
                                nrows=1,
                                figsize=(7,3))

ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7, 4))

someaxes ["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes ["ax3"].plot(x1,y1)
plt. show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize=(7, 4),
                                    layout = "constrained")
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes['ax1'].set_xlabel("Another Label", fontsize=18)
someaxes["ax2"].set_xlabel("Another Label", fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious", fontsize=18)
plt. show()

# %%
x = np.array(["Luffy","Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110,180,240,99,220])
y2 = np.array([170,100,90,120,50])

fig, ax = plt.subplots(figsize=(7,3))

ax.bar(x,y1,
color = 'indigo')
ax.plot(x,y2,
color = 'red')

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

ax.errorbar(x,y2,yerr = y2_sd,fmt ="none")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

ax.errorbar(x, y2,
yerr = y2_sd,
fmt = "none",
ecolor = "indigo",
elinewidth = 4,
capsize = 6,
capthick = 4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Class 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
from PIL import Image # to open images
from io import BytesIO # to store images

# %%
response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
image = Image.open(image_file)

# make sample data
x = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# %%
fig, ax = plt.subplots(figsize=(7, 3))
#call both bar and plot elements to the same axes (ax)
ax.plot(x, y2, color = "red")

ax_image = fig.add_axes([0.1,#x coordinate
                         0.11, #y coordinate
                         0.15, #image width
                         0.35]) #image height

ax_image.imshow(image)
ax_image.axis('off')
plt.show()

# %% [markdown]
# Class 5

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('whitegrid') #alter appearance of plot using premade styles
sns.lineplot(data=tips, # choose dataset
x='total_bill'
, # define x variable
y='tip') # define y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('darkgrid') #alter appearance of plot using premade styles
sns.lineplot(data=tips, # choose dataset
x='total_bill'
, # define x variable
y='tip') # define y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('ticks') #alter appearance of plot using premade styles
sns.lineplot(data=tips, # choose dataset
x='total_bill'
, # define x variable
y='tip') # define y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tipgraph = sns.lineplot(data=tips,x='total_bill', y='tip')
#set title, x label, y label
tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill ($)',ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10, 3))

tipgraph = sns.lineplot(data=tips,x='total_bill', y='tip')
tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill ($)',ylabel='Tip Amount ($)')
tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill ($)',ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10, 3))
#customize colour, line style, marker style:
tipgraph = sns.lineplot(data=tips,x='total_bill',y='tip',color = 'hotpink',linestyle = '--',linewidth = 3,marker = 'o',markerfacecolor = 'indigo')
tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill ($)',ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
#Changing the colours of markers depending on variable "day", change style of markers according to variable "time"
tipgraph = sns.scatterplot(data=tips, x='total_bill',y='tip', style = 'time' #change marker style according to the time variable
                           ,hue ='day' #change hue (colour) according to the day variable
                           , palette = ['purple','hotpink','deepskyblue','yellowgreen']) #colour palette

tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill ($)',ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
#pairplot allows for comparison of variables
sns.pairplot(data = tips,hue = 'day')

# %%
#Replot allows user to explore specific levels between variables
daysplot = sns.relplot(data=tips,x="total_bill",y="tip"
,hue="sex" #different colours for each "sex" variable data point (male/female)
,col="day" #columns are "day" variable (this results in 4 separate graphs ("columns" because there are 4 different data points under variable "day")
,kind="scatter" #scatter plot
,col_wrap=2 #column is wrapped as 2 columns (2 columns per row). If col_wrap was 4, all 4 graphs would be displayed in 1 line side by side.
)

# %%
import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
#make figure object (graph)
graph = go.Figure()

#add a trace to the graph object (bar plot)
graph.add_trace(go.Bar(x=x1, y=y1)) #x1 y1 data comes from above code block
#Add figure title and axes titles
graph.update_layout(title="Pirate Scores",xaxis_title="Pirates",yaxis_title="Score")

graph.show()
#note that hovering your cursor over the bars allows more data to be displayed, and there are options to zoom in/out, pan, select, etc. in the top right corner of the figure output

# %%
#make graph (graph object go.figure, making it a scatter plot this time)
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers'
, # mode = "markers" means we want points for a scatter plot

#make dictionary for markers
marker=dict(
size=15, # point size
color='hotpink'
, # point colour
opacity=1, # point transparency/alpha

#make dictionary for lines
line=dict(width=5, color='purple') # point outline
)))
#Layout updates to title, axes titles, image size
graph.update_layout(title='Interactive Pirate Plot',xaxis_title='Pirates',yaxis_title='Scores',width=500, height=500)

# %%
# !pip install wordcloud
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    ---------------------------------------  297.0/300.6 kB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 300.6/300.6 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
text = " ".join(each for each in df.quote)

wordcloud = WordCloud(background_color="white",
colormap = 'inferno').generate(text)

fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud,
interpolation='bilinear') 
ax.axis("off") #
plt.show()

# %%
# !pip install matplotlib-venn
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# Out:
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.1.tar.gz (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 969.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.8.4)
# Requirement already satisfied: numpy in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.26.4)
# Requirement already satisfied: scipy in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\luizp\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45335 sha256=bba795cf1c3fa91aeb2906bd8db4b78b69eac1046c242e8ba0348cbdab1aae06
#   Stored in directory: c:\users\luizp\appdata\local\pip\cache\wheels\5c\4b\48\d68a6531b1e1e7411520ab9f395994eb1ee2ffafd6837b7f6c
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-1.1.1

# %%
A = set(["apple","banana","watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])
diagram = venn2_unweighted([A, B],set_labels = ('Fruits'
,'Pies'),set_colors=("blue","red"),alpha=0.5)

plt.show()
# Out:
# c:\Users\luizp\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib_venn\_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.

# %%
A = set(["apple","banana","watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])
diagram = venn2_unweighted([A, B],set_labels = ('Fruits'
,'Pies'),set_colors=("blue","red"),alpha=0.5)

#make the left circle (only things that are in set A, not set B)
diagram.get_label_by_id("10").set_text("\n".join(A - B))
#make middle (items in both set A and set B)
diagram.get_label_by_id("11").set_text("\n".join(A & B))
#make right circle (only things that are in set B, and not set A)
diagram.get_label_by_id("01").set_text("\n".join(B - A))

#note that "\n" puts each item in the set on a new line instead of showing them in a single line

plt.show()
